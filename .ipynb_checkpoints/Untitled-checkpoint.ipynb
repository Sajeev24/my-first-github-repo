# %% [markdown]
# We are trying to build a POC to prove if retraining SpaCy's pretrained model on private data improves the performance. This logically seems so. But need to see by how much does it improve.
#
# One hurdle in this process is that the annotation labels that SpaCy's NER model is trained is different than that of our dataset. So, we would need to find the equivalence between the labels to make this happen. You can find the labels that SpaCy parses on its [documentation page](https://spacy.io/api/annotation#named-entities). Whereas  [our dataset](https://www.kaggle.com/alaakhaled/conll003-englishversion) has these labels: PER, ORG, LOC, MISC
#
# The following are the dependencies of this notebook. Please make sure they are installed before running this notebook:
# * SpaCy
# * Sklearn
#
# We need to compare the performance on the following scenarios:
# * Performance on spaCy's vanilla pretrained model 'en_core_web_md'
# * Performance after retraining vanilla model ('en_core_web_md') on training dataset.
# * Performance on a model obtained by training from scratch on a training dataset.
# * Performance on spaCy's vanilla pretrained model 'en_core_web_lg' which is the <b>largest</b> model
# * Performance after retraining vanilla model ('en_core_web_lg') on training dataset.

# %%
import json
from pprint import pprint
import spacy 
from sklearn.metrics import precision_recall_fscore_support
from spacy.gold import GoldParse
from sklearn.metrics import accuracy_score

# %% [markdown]
# Load the training json file from the disk

# %%
with open('./train.json', 'r') as f:
    read_bytes = f.read()
print(len(read_bytes))
train_json = json.loads(read_bytes)
train_json
# Out:
# 26772141
# [{'id': 0,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '-DOCSTART-',
#         'tag': '-X-',
#         'ner': 'O'}]}]}]},
#  {'id': 1,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'EU',
#         'tag': 'NNP',
#         'ner': 'U-ORG'},
#        {'orth': 'rejects', 'tag': 'VBZ', 'ner': 'O'},
#        {'orth': 'German', 'tag': 'JJ', 'ner': 'U-MISC'},
#        {'orth': 'call', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'boycott', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'British', 'tag': 'JJ', 'ner': 'U-MISC'},
#        {'orth': 'lamb', 'tag': 'NN', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 2,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Peter',
#         'tag': 'NNP',
#         'ner': 'B-PER'},
#        {'orth': 'Blackburn', 'tag': 'NNP', 'ner': 'L-PER'}]}]}]},
#  {'id': 3,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'BRUSSELS',
#         'tag': 'NNP',
#         'ner': 'U-LOC'},
#        {'orth': '1996-08-22', 'tag': 'CD', 'ner': 'O'}]}]}]},
#  {'id': 4,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'The',
#         'tag': 'DT',
#         'ner': 'O'},
#        {'orth': 'European', 'tag': 'NNP', 'ner': 'B-ORG'},
#        {'orth': 'Commission', 'tag': 'NNP', 'ner': 'L-ORG'},
#        {'orth': 'said', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'on', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Thursday', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'it', 'tag': 'PRP', 'ner': 'O'},
#        {'orth': 'disagreed', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'with', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'German', 'tag': 'JJ', 'ner': 'U-MISC'},
#        {'orth': 'advice', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'consumers', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'shun', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'British', 'tag': 'JJ', 'ner': 'U-MISC'},
#        {'orth': 'lamb', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'until', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'scientists', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'determine', 'tag': 'VBP', 'ner': 'O'},
#        {'orth': 'whether', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'mad', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'cow', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'disease', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'can', 'tag': 'MD', 'ner': 'O'},
#        {'orth': 'be', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'transmitted', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'sheep', 'tag': 'NN', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 5,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Germany',
#         'tag': 'NNP',
#         'ner': 'U-LOC'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'representative', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'European', 'tag': 'NNP', 'ner': 'B-ORG'},
#        {'orth': 'Union', 'tag': 'NNP', 'ner': 'L-ORG'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'veterinary', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'committee', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'Werner', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Zwingmann', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': 'said', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'on', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Wednesday', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'consumers', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'should', 'tag': 'MD', 'ner': 'O'},
#        {'orth': 'buy', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'sheepmeat', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'from', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'countries', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'other', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'than', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Britain', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'until', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'scientific', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'advice', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'was', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'clearer', 'tag': 'JJR', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 6,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '"',
#         'tag': '"',
#         'ner': 'O'},
#        {'orth': 'We', 'tag': 'PRP', 'ner': 'O'},
#        {'orth': 'do', 'tag': 'VBP', 'ner': 'O'},
#        {'orth': "n't", 'tag': 'RB', 'ner': 'O'},
#        {'orth': 'support', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'any', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'such', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'recommendation', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'because', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'we', 'tag': 'PRP', 'ner': 'O'},
#        {'orth': 'do', 'tag': 'VBP', 'ner': 'O'},
#        {'orth': "n't", 'tag': 'RB', 'ner': 'O'},
#        {'orth': 'see', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'any', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'grounds', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'for', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'it', 'tag': 'PRP', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': '"', 'tag': '"', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'Commission', 'tag': 'NNP', 'ner': 'U-ORG'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'chief', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'spokesman', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'Nikolaus', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'van', 'tag': 'NNP', 'ner': 'I-PER'},
#        {'orth': 'der', 'tag': 'FW', 'ner': 'I-PER'},
#        {'orth': 'Pas', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': 'told', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'news', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'briefing', 'tag': 'NN', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 7,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'He',
#         'tag': 'PRP',
#         'ner': 'O'},
#        {'orth': 'said', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'further', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'scientific', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'study', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'was', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'required', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'and', 'tag': 'CC', 'ner': 'O'},
#        {'orth': 'if', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'it', 'tag': 'PRP', 'ner': 'O'},
#        {'orth': 'was', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'found', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'that', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'action', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'was', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'needed', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'it', 'tag': 'PRP', 'ner': 'O'},
#        {'orth': 'should', 'tag': 'MD', 'ner': 'O'},
#        {'orth': 'be', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'taken', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'by', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'European', 'tag': 'NNP', 'ner': 'B-ORG'},
#        {'orth': 'Union', 'tag': 'NNP', 'ner': 'L-ORG'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 8,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'He',
#         'tag': 'PRP',
#         'ner': 'O'},
#        {'orth': 'said', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'proposal', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'last', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'month', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'by', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'EU', 'tag': 'NNP', 'ner': 'U-ORG'},
#        {'orth': 'Farm', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'Commissioner', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'Franz', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Fischler', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'ban', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'sheep', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'brains', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'spleens', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'and', 'tag': 'CC', 'ner': 'O'},
#        {'orth': 'spinal', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'cords', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'from', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'human', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'and', 'tag': 'CC', 'ner': 'O'},
#        {'orth': 'animal', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'food', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'chains', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'was', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'highly', 'tag': 'RB', 'ner': 'O'},
#        {'orth': 'specific', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'and', 'tag': 'CC', 'ner': 'O'},
#        {'orth': 'precautionary', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'move', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'protect', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'human', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'health', 'tag': 'NN', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 9,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Fischler',
#         'tag': 'JJR',
#         'ner': 'U-PER'},
#        {'orth': 'proposed', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'EU-wide', 'tag': 'NNP', 'ner': 'U-MISC'},
#        {'orth': 'measures', 'tag': 'VBZ', 'ner': 'O'},
#        {'orth': 'after', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'reports', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'from', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Britain', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'and', 'tag': 'CC', 'ner': 'O'},
#        {'orth': 'France', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'that', 'tag': 'WDT', 'ner': 'O'},
#        {'orth': 'under', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'laboratory', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'conditions', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'sheep', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'could', 'tag': 'MD', 'ner': 'O'},
#        {'orth': 'contract', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'Bovine', 'tag': 'NNP', 'ner': 'B-MISC'},
#        {'orth': 'Spongiform', 'tag': 'NNP', 'ner': 'I-MISC'},
#        {'orth': 'Encephalopathy', 'tag': 'NNP', 'ner': 'L-MISC'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'BSE', 'tag': 'NNP', 'ner': 'U-MISC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': '--', 'tag': ':', 'ner': 'O'},
#        {'orth': 'mad', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'cow', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'disease', 'tag': 'NN', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 10,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'But',
#         'tag': 'CC',
#         'ner': 'O'},
#        {'orth': 'Fischler', 'tag': 'NNP', 'ner': 'U-PER'},
#        {'orth': 'agreed', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'review', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'his', 'tag': 'PRP$', 'ner': 'O'},
#        {'orth': 'proposal', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'after', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'EU', 'tag': 'NNP', 'ner': 'U-ORG'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'standing', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'veterinary', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'committee', 'tag': 'NN', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'mational', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'animal', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'health', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'officials', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'questioned', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'if', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'such', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'action', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'was', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'justified', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'as', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'there', 'tag': 'RB', 'ner': 'O'},
#        {'orth': 'was', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'only', 'tag': 'RB', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'slight', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'risk', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'human', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'health', 'tag': 'NN', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 11,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Spanish',
#         'tag': 'NNP',
#         'ner': 'U-MISC'},
#        {'orth': 'Farm', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'Minister', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'Loyola', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'de', 'tag': 'NNP', 'ner': 'I-PER'},
#        {'orth': 'Palacio', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': 'had', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'earlier', 'tag': 'RBR', 'ner': 'O'},
#        {'orth': 'accused', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'Fischler', 'tag': 'NNP', 'ner': 'U-PER'},
#        {'orth': 'at', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'an', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'EU', 'tag': 'JJ', 'ner': 'U-ORG'},
#        {'orth': 'farm', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'ministers', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': "'", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'meeting', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'causing', 'tag': 'VBG', 'ner': 'O'},
#        {'orth': 'unjustified', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'alarm', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'through', 'tag': 'IN', 'ner': 'O'},
#        {'orth': '"', 'tag': '"', 'ner': 'O'},
#        {'orth': 'dangerous', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'generalisation', 'tag': 'NN', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'},
#        {'orth': '"', 'tag': '"', 'ner': 'O'}]}]}]},
#  {'id': 12,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '.',
#         'tag': '.',
#         'ner': 'O'}]}]}]},
#  {'id': 13,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Only',
#         'tag': 'RB',
#         'ner': 'O'},
#        {'orth': 'France', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'and', 'tag': 'CC', 'ner': 'O'},
#        {'orth': 'Britain', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'backed', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'Fischler', 'tag': 'NNP', 'ner': 'U-PER'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'proposal', 'tag': 'NN', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 14,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'The',
#         'tag': 'DT',
#         'ner': 'O'},
#        {'orth': 'EU', 'tag': 'NNP', 'ner': 'U-ORG'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'scientific', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'veterinary', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'and', 'tag': 'CC', 'ner': 'O'},
#        {'orth': 'multidisciplinary', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'committees', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'are', 'tag': 'VBP', 'ner': 'O'},
#        {'orth': 'due', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 're-examine', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'issue', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'early', 'tag': 'RB', 'ner': 'O'},
#        {'orth': 'next', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'month', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'and', 'tag': 'CC', 'ner': 'O'},
#        {'orth': 'make', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'recommendations', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'senior', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'veterinary', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'officials', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 15,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Sheep',
#         'tag': 'NNP',
#         'ner': 'O'},
#        {'orth': 'have', 'tag': 'VBP', 'ner': 'O'},
#        {'orth': 'long', 'tag': 'RB', 'ner': 'O'},
#        {'orth': 'been', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'known', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'contract', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'scrapie', 'tag': 'NN', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'brain-wasting', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'disease', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'similar', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'BSE', 'tag': 'NNP', 'ner': 'U-MISC'},
#        {'orth': 'which', 'tag': 'WDT', 'ner': 'O'},
#        {'orth': 'is', 'tag': 'VBZ', 'ner': 'O'},
#        {'orth': 'believed', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'have', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'been', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'transferred', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'cattle', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'through', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'feed', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'containing', 'tag': 'VBG', 'ner': 'O'},
#        {'orth': 'animal', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'waste', 'tag': 'NN', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 16,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'British',
#         'tag': 'JJ',
#         'ner': 'U-MISC'},
#        {'orth': 'farmers', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'denied', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'on', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Thursday', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'there', 'tag': 'EX', 'ner': 'O'},
#        {'orth': 'was', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'any', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'danger', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'human', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'health', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'from', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'their', 'tag': 'PRP$', 'ner': 'O'},
#        {'orth': 'sheep', 'tag': 'NN', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'but', 'tag': 'CC', 'ner': 'O'},
#        {'orth': 'expressed', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'concern', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'that', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'German', 'tag': 'JJ', 'ner': 'U-MISC'},
#        {'orth': 'government', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'advice', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'consumers', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'avoid', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'British', 'tag': 'JJ', 'ner': 'U-MISC'},
#        {'orth': 'lamb', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'might', 'tag': 'MD', 'ner': 'O'},
#        {'orth': 'influence', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'consumers', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'across', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Europe', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 17,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '"',
#         'tag': '"',
#         'ner': 'O'},
#        {'orth': 'What', 'tag': 'WP', 'ner': 'O'},
#        {'orth': 'we', 'tag': 'PRP', 'ner': 'O'},
#        {'orth': 'have', 'tag': 'VBP', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'be', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'extremely', 'tag': 'RB', 'ner': 'O'},
#        {'orth': 'careful', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'is', 'tag': 'VBZ', 'ner': 'O'},
#        {'orth': 'how', 'tag': 'WRB', 'ner': 'O'},
#        {'orth': 'other', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'countries', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'are', 'tag': 'VBP', 'ner': 'O'},
#        {'orth': 'going', 'tag': 'VBG', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'take', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'Germany', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'lead', 'tag': 'NN', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': '"', 'tag': '"', 'ner': 'O'},
#        {'orth': 'Welsh', 'tag': 'NNP', 'ner': 'B-ORG'},
#        {'orth': 'National', 'tag': 'NNP', 'ner': 'I-ORG'},
#        {'orth': 'Farmers', 'tag': 'NNP', 'ner': 'I-ORG'},
#        {'orth': "'", 'tag': 'POS', 'ner': 'I-ORG'},
#        {'orth': 'Union', 'tag': 'NNP', 'ner': 'L-ORG'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'NFU', 'tag': 'NNP', 'ner': 'U-ORG'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': 'chairman', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'John', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Lloyd', 'tag': 'NNP', 'ner': 'I-PER'},
#        {'orth': 'Jones', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': 'said', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'on', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'BBC', 'tag': 'NNP', 'ner': 'B-ORG'},
#        {'orth': 'radio', 'tag': 'NN', 'ner': 'L-ORG'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 18,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Bonn',
#         'tag': 'NNP',
#         'ner': 'U-LOC'},
#        {'orth': 'has', 'tag': 'VBZ', 'ner': 'O'},
#        {'orth': 'led', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'efforts', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'protect', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'public', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'health', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'after', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'consumer', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'confidence', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'collapsed', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'in', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'March', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'after', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'British', 'tag': 'JJ', 'ner': 'U-MISC'},
#        {'orth': 'report', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'suggested', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'humans', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'could', 'tag': 'MD', 'ner': 'O'},
#        {'orth': 'contract', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'an', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'illness', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'similar', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'mad', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'cow', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'disease', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'by', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'eating', 'tag': 'VBG', 'ner': 'O'},
#        {'orth': 'contaminated', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'beef', 'tag': 'NN', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 19,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Germany',
#         'tag': 'NNP',
#         'ner': 'U-LOC'},
#        {'orth': 'imported', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': '47,600', 'tag': 'CD', 'ner': 'O'},
#        {'orth': 'sheep', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'from', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Britain', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'last', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'year', 'tag': 'NN', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'nearly', 'tag': 'RB', 'ner': 'O'},
#        {'orth': 'half', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'total', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'imports', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 20,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'It',
#         'tag': 'PRP',
#         'ner': 'O'},
#        {'orth': 'brought', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'in', 'tag': 'IN', 'ner': 'O'},
#        {'orth': '4,275', 'tag': 'CD', 'ner': 'O'},
#        {'orth': 'tonnes', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'British', 'tag': 'JJ', 'ner': 'U-MISC'},
#        {'orth': 'mutton', 'tag': 'NN', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'some', 'tag': 'DT', 'ner': 'O'},
#        {'orth': '10', 'tag': 'CD', 'ner': 'O'},
#        {'orth': 'percent', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'overall', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'imports', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 21,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '-DOCSTART-',
#         'tag': '-X-',
#         'ner': 'O'}]}]}]},
#  {'id': 22,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Rare',
#         'tag': 'NNP',
#         'ner': 'O'},
#        {'orth': 'Hendrix', 'tag': 'NNP', 'ner': 'U-PER'},
#        {'orth': 'song', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'draft', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'sells', 'tag': 'VBZ', 'ner': 'O'},
#        {'orth': 'for', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'almost', 'tag': 'RB', 'ner': 'O'},
#        {'orth': '$', 'tag': '$', 'ner': 'O'},
#        {'orth': '17,000', 'tag': 'CD', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 23,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'LONDON',
#         'tag': 'NNP',
#         'ner': 'U-LOC'},
#        {'orth': '1996-08-22', 'tag': 'CD', 'ner': 'O'}]}]}]},
#  {'id': 24,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'A',
#         'tag': 'DT',
#         'ner': 'O'},
#        {'orth': 'rare', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'early', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'handwritten', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'draft', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'song', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'by', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'U.S.', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'guitar', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'legend', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'Jimi', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Hendrix', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': 'was', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'sold', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'for', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'almost', 'tag': 'RB', 'ner': 'O'},
#        {'orth': '$', 'tag': '$', 'ner': 'O'},
#        {'orth': '17,000', 'tag': 'CD', 'ner': 'O'},
#        {'orth': 'on', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Thursday', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'at', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'an', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'auction', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'some', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'late', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'musician', 'tag': 'NN', 'ner': 'O'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'favourite', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'possessions', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 25,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'A',
#         'tag': 'DT',
#         'ner': 'O'},
#        {'orth': 'Florida', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'restaurant', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'paid', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': '10,925', 'tag': 'CD', 'ner': 'O'},
#        {'orth': 'pounds', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': '$', 'tag': '$', 'ner': 'O'},
#        {'orth': '16,935', 'tag': 'CD', 'ner': 'O'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': 'for', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'draft', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': '"', 'tag': '"', 'ner': 'O'},
#        {'orth': 'Ai', 'tag': 'VBZ', 'ner': 'B-MISC'},
#        {'orth': "n't", 'tag': 'RB', 'ner': 'I-MISC'},
#        {'orth': 'no', 'tag': 'DT', 'ner': 'I-MISC'},
#        {'orth': 'telling', 'tag': 'VBG', 'ner': 'L-MISC'},
#        {'orth': '"', 'tag': '"', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'which', 'tag': 'WDT', 'ner': 'O'},
#        {'orth': 'Hendrix', 'tag': 'NNP', 'ner': 'U-PER'},
#        {'orth': 'penned', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'on', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'piece', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'London', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'hotel', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'stationery', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'in', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'late', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': '1966', 'tag': 'CD', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 26,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'At',
#         'tag': 'IN',
#         'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'end', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'January', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': '1967', 'tag': 'CD', 'ner': 'O'},
#        {'orth': 'concert', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'in', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'English', 'tag': 'JJ', 'ner': 'U-MISC'},
#        {'orth': 'city', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Nottingham', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'he', 'tag': 'PRP', 'ner': 'O'},
#        {'orth': 'threw', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'sheet', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'paper', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'into', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'audience', 'tag': 'NN', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'where', 'tag': 'WRB', 'ner': 'O'},
#        {'orth': 'it', 'tag': 'PRP', 'ner': 'O'},
#        {'orth': 'was', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'retrieved', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'by', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'fan', 'tag': 'NN', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 27,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Buyers',
#         'tag': 'NNS',
#         'ner': 'O'},
#        {'orth': 'also', 'tag': 'RB', 'ner': 'O'},
#        {'orth': 'snapped', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'up', 'tag': 'RB', 'ner': 'O'},
#        {'orth': '16', 'tag': 'CD', 'ner': 'O'},
#        {'orth': 'other', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'items', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'that', 'tag': 'WDT', 'ner': 'O'},
#        {'orth': 'were', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'put', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'up', 'tag': 'RP', 'ner': 'O'},
#        {'orth': 'for', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'auction', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'by', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Hendrix', 'tag': 'NNP', 'ner': 'U-PER'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'former', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'girlfriend', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'Kathy', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Etchingham', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'who', 'tag': 'WP', 'ner': 'O'},
#        {'orth': 'lived', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'with', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'him', 'tag': 'PRP', 'ner': 'O'},
#        {'orth': 'from', 'tag': 'IN', 'ner': 'O'},
#        {'orth': '1966', 'tag': 'CD', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': '1969', 'tag': 'CD', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 28,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'They',
#         'tag': 'PRP',
#         'ner': 'O'},
#        {'orth': 'included', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'black', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'lacquer', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'and', 'tag': 'CC', 'ner': 'O'},
#        {'orth': 'mother', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'pearl', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'inlaid', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'box', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'used', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'by', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Hendrix', 'tag': 'NNP', 'ner': 'U-PER'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'store', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'his', 'tag': 'PRP$', 'ner': 'O'},
#        {'orth': 'drugs', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'which', 'tag': 'WDT', 'ner': 'O'},
#        {'orth': 'an', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'anonymous', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'Australian', 'tag': 'JJ', 'ner': 'U-MISC'},
#        {'orth': 'purchaser', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'bought', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'for', 'tag': 'IN', 'ner': 'O'},
#        {'orth': '5,060', 'tag': 'CD', 'ner': 'O'},
#        {'orth': 'pounds', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': '$', 'tag': '$', 'ner': 'O'},
#        {'orth': '7,845', 'tag': 'CD', 'ner': 'O'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 29,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'The',
#         'tag': 'DT',
#         'ner': 'O'},
#        {'orth': 'guitarist', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'died', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'drugs', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'overdose', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'in', 'tag': 'IN', 'ner': 'O'},
#        {'orth': '1970', 'tag': 'CD', 'ner': 'O'},
#        {'orth': 'aged', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': '27', 'tag': 'CD', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 30,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '-DOCSTART-',
#         'tag': '-X-',
#         'ner': 'O'}]}]}]},
#  {'id': 31,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'China',
#         'tag': 'NNP',
#         'ner': 'U-LOC'},
#        {'orth': 'says', 'tag': 'VBZ', 'ner': 'O'},
#        {'orth': 'Taiwan', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'spoils', 'tag': 'VBZ', 'ner': 'O'},
#        {'orth': 'atmosphere', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'for', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'talks', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 32,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'BEIJING',
#         'tag': 'VBG',
#         'ner': 'U-LOC'},
#        {'orth': '1996-08-22', 'tag': 'CD', 'ner': 'O'}]}]}]},
#  {'id': 33,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'China',
#         'tag': 'NNP',
#         'ner': 'U-LOC'},
#        {'orth': 'on', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Thursday', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'accused', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'Taipei', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'spoiling', 'tag': 'VBG', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'atmosphere', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'for', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'resumption', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'talks', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'across', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'Taiwan', 'tag': 'NNP', 'ner': 'B-LOC'},
#        {'orth': 'Strait', 'tag': 'NNP', 'ner': 'L-LOC'},
#        {'orth': 'with', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'visit', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'Ukraine', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'by', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Taiwanese', 'tag': 'NNP', 'ner': 'U-MISC'},
#        {'orth': 'Vice', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'President', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'Lien', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Chan', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': 'this', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'week', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'that', 'tag': 'WDT', 'ner': 'O'},
#        {'orth': 'infuriated', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'Beijing', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 34,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Speaking',
#         'tag': 'VBG',
#         'ner': 'O'},
#        {'orth': 'only', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'hours', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'after', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Chinese', 'tag': 'JJ', 'ner': 'U-MISC'},
#        {'orth': 'state', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'media', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'said', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'time', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'was', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'right', 'tag': 'RB', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'engage', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'in', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'political', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'talks', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'with', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Taiwan', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Foreign', 'tag': 'NNP', 'ner': 'B-ORG'},
#        {'orth': 'Ministry', 'tag': 'NNP', 'ner': 'L-ORG'},
#        {'orth': 'spokesman', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'Shen', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Guofang', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': 'told', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'Reuters', 'tag': 'NNP', 'ner': 'U-ORG'},
#        {'orth': ':', 'tag': ':', 'ner': 'O'},
#        {'orth': '"', 'tag': '"', 'ner': 'O'},
#        {'orth': 'The', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'necessary', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'atmosphere', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'for', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'opening', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'talks', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'has', 'tag': 'VBZ', 'ner': 'O'},
#        {'orth': 'been', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'disrupted', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'by', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'Taiwan', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'authorities', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'},
#        {'orth': '"', 'tag': '"', 'ner': 'O'}]}]}]},
#  {'id': 35,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'State',
#         'tag': 'NN',
#         'ner': 'O'},
#        {'orth': 'media', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'quoted', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'China', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'top', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'negotiator', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'with', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Taipei', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Tang', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Shubei', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'as', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'telling', 'tag': 'VBG', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'visiting', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'group', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'from', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Taiwan', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'on', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Wednesday', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'that', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'it', 'tag': 'PRP', 'ner': 'O'},
#        {'orth': 'was', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'time', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'for', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'rivals', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'hold', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'political', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'talks', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 36,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '"',
#         'tag': '"',
#         'ner': 'O'},
#        {'orth': 'Now', 'tag': 'RB', 'ner': 'O'},
#        {'orth': 'is', 'tag': 'VBZ', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'time', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'for', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'two', 'tag': 'CD', 'ner': 'O'},
#        {'orth': 'sides', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'engage', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'in', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'political', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'talks', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': '...', 'tag': ':', 'ner': 'O'}]}]}]},
#  {'id': 37,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'that',
#         'tag': 'WDT',
#         'ner': 'O'},
#        {'orth': 'is', 'tag': 'VBZ', 'ner': 'O'},
#        {'orth': 'to', 'tag': 'TO', 'ner': 'O'},
#        {'orth': 'end', 'tag': 'VB', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'state', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'hostility', 'tag': 'NN', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': '"', 'tag': '"', 'ner': 'O'},
#        {'orth': 'Thursday', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'overseas', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'edition', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'People', 'tag': 'NNPS', 'ner': 'B-ORG'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'I-ORG'},
#        {'orth': 'Daily', 'tag': 'JJ', 'ner': 'L-ORG'},
#        {'orth': 'quoted', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'Tang', 'tag': 'NNP', 'ner': 'U-PER'},
#        {'orth': 'as', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'saying', 'tag': 'VBG', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 38,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'The',
#         'tag': 'DT',
#         'ner': 'O'},
#        {'orth': 'foreign', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'ministry', 'tag': 'NN', 'ner': 'O'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'Shen', 'tag': 'NNP', 'ner': 'U-ORG'},
#        {'orth': 'told', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'Reuters', 'tag': 'NNP', 'ner': 'B-ORG'},
#        {'orth': 'Television', 'tag': 'NNP', 'ner': 'L-ORG'},
#        {'orth': 'in', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'an', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'interview', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'he', 'tag': 'PRP', 'ner': 'O'},
#        {'orth': 'had', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'read', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'reports', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Tang', 'tag': 'NNP', 'ner': 'U-PER'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': 'comments', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'but', 'tag': 'CC', 'ner': 'O'},
#        {'orth': 'gave', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'no', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'details', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'of', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'why', 'tag': 'WRB', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'negotiator', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'had', 'tag': 'VBD', 'ner': 'O'},
#        {'orth': 'considered', 'tag': 'VBN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'time', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'right', 'tag': 'RB', 'ner': 'O'},
#        {'orth': 'for', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'talks', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'with', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Taiwan', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'which', 'tag': 'WDT', 'ner': 'O'},
#        {'orth': 'Beijing', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': 'considers', 'tag': 'VBZ', 'ner': 'O'},
#        {'orth': 'a', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'renegade', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'province', 'tag': 'NN', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 39,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'China',
#         'tag': 'NNP',
#         'ner': 'U-LOC'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'which', 'tag': 'WDT', 'ner': 'O'},
#        {'orth': 'has', 'tag': 'VBZ', 'ner': 'O'},
#        {'orth': 'long', 'tag': 'RB', 'ner': 'O'},
# ...
#        {'orth': 'women', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': '1,000', 'tag': 'CD', 'ner': 'O'},
#        {'orth': 'metres', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': 'and', 'tag': 'CC', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'men', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': "'s", 'tag': 'POS', 'ner': 'O'},
#        {'orth': '3,000', 'tag': 'CD', 'ner': 'O'},
#        {'orth': 'metres', 'tag': 'NNS', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 972,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '-DOCSTART-',
#         'tag': '-X-',
#         'ner': 'O'}]}]}]},
#  {'id': 973,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'GOLF',
#         'tag': 'NN',
#         'ner': 'O'},
#        {'orth': '-', 'tag': ':', 'ner': 'O'},
#        {'orth': 'GERMAN', 'tag': 'NNP', 'ner': 'B-MISC'},
#        {'orth': 'OPEN', 'tag': 'NNP', 'ner': 'L-MISC'},
#        {'orth': 'FIRST', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'ROUND', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': 'SCORES', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': '.', 'tag': '.', 'ner': 'O'}]}]}]},
#  {'id': 974,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'STUTTGART',
#         'tag': 'NNP',
#         'ner': 'U-LOC'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Germany', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': '1996-08-22', 'tag': 'CD', 'ner': 'O'}]}]}]},
#  {'id': 975,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Leading',
#         'tag': 'JJ',
#         'ner': 'O'},
#        {'orth': 'first', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': 'round', 'tag': 'NN', 'ner': 'O'}]}]}]},
#  {'id': 976,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'scores',
#         'tag': 'NNS',
#         'ner': 'O'},
#        {'orth': 'in', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'the', 'tag': 'DT', 'ner': 'O'},
#        {'orth': 'German', 'tag': 'NNP', 'ner': 'B-MISC'},
#        {'orth': 'Open', 'tag': 'NNP', 'ner': 'L-MISC'},
#        {'orth': 'golf', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'championship', 'tag': 'NN', 'ner': 'O'},
#        {'orth': 'on', 'tag': 'IN', 'ner': 'O'},
#        {'orth': 'Thursday', 'tag': 'NNP', 'ner': 'O'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Britain', 'tag': 'NNP', 'ner': 'U-LOC'}]}]}]},
#  {'id': 977,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'unless',
#         'tag': 'IN',
#         'ner': 'O'},
#        {'orth': 'stated', 'tag': 'JJ', 'ner': 'O'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ':', 'tag': ':', 'ner': 'O'}]}]}]},
#  {'id': 978,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '62',
#         'tag': 'CD',
#         'ner': 'O'},
#        {'orth': 'Paul', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Broadhurst', 'tag': 'NNP', 'ner': 'L-PER'}]}]}]},
#  {'id': 979,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '63',
#         'tag': 'CD',
#         'ner': 'O'},
#        {'orth': 'Raymond', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Russell', 'tag': 'NNP', 'ner': 'L-PER'}]}]}]},
#  {'id': 980,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '64',
#         'tag': 'CD',
#         'ner': 'O'},
#        {'orth': 'David', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'J.', 'tag': 'NNP', 'ner': 'I-PER'},
#        {'orth': 'Russell', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Michael', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Campbell', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'New', 'tag': 'NNP', 'ner': 'B-LOC'},
#        {'orth': 'Zealand', 'tag': 'NNP', 'ner': 'L-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Ian', 'tag': 'NNP', 'ner': 'U-PER'}]}]}]},
#  {'id': 981,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Woosnam',
#         'tag': 'NNP',
#         'ner': 'U-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Bernhard', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Langer', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Germany', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Ronan', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Rafferty', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Mats', 'tag': 'NNS', 'ner': 'U-PER'}]}]}]},
#  {'id': 982,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Lanner',
#         'tag': 'NNP',
#         'ner': 'U-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Sweden', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Wayne', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Riley', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Australia', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'}]}]}]},
#  {'id': 983,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '65',
#         'tag': 'CD',
#         'ner': 'O'},
#        {'orth': 'Eamonn', 'tag': 'VBG', 'ner': 'B-PER'},
#        {'orth': 'Darcy', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Ireland', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Per', 'tag': 'IN', 'ner': 'B-PER'},
#        {'orth': 'Nyman', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Sweden', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Russell', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Claydon', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'}]}]}]},
#  {'id': 984,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Mark',
#         'tag': 'NNP',
#         'ner': 'B-PER'},
#        {'orth': 'Roe', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Retief', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Goosen', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'South', 'tag': 'NNP', 'ner': 'B-LOC'},
#        {'orth': 'Africa', 'tag': 'NNP', 'ner': 'L-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Carl', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Suneson', 'tag': 'NNP', 'ner': 'L-PER'}]}]}]},
#  {'id': 985,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '66',
#         'tag': 'CD',
#         'ner': 'O'},
#        {'orth': 'Stephen', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Field', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Paul', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Lawrie', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Ian', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Pyman', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Max', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Anglert', 'tag': 'JJ', 'ner': 'L-PER'}]}]}]},
#  {'id': 986,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '(',
#         'tag': '(',
#         'ner': 'O'},
#        {'orth': 'Sweden', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Miles', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Tunnicliff', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Christian', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Cevaer', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'France', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'}]}]}]},
#  {'id': 987,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Des',
#         'tag': 'NNP',
#         'ner': 'B-PER'},
#        {'orth': 'Smyth', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Ireland', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'David', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Carter', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Lee', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Westwood', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Greg', 'tag': 'NNP', 'ner': 'U-PER'}]}]}]},
#  {'id': 988,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Chalmers',
#         'tag': 'NNP',
#         'ner': 'U-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Australia', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Miguel', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Angel', 'tag': 'NNP', 'ner': 'I-PER'},
#        {'orth': 'Martin', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Spain', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'}]}]}]},
#  {'id': 989,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Thomas',
#         'tag': 'NNP',
#         'ner': 'B-PER'},
#        {'orth': 'Bjorn', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Denmark', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Fernando', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Roca', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Spain', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Derrick', 'tag': 'NNP', 'ner': 'U-PER'}]}]}]},
#  {'id': 990,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Cooper',
#         'tag': 'NNP',
#         'ner': 'U-PER'}]}]}]},
#  {'id': 991,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '67',
#         'tag': 'CD',
#         'ner': 'O'},
#        {'orth': 'Jeff', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Hawksworth', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Padraig', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Harrington', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Ireland', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Michael', 'tag': 'NNP', 'ner': 'U-PER'}]}]}]},
#  {'id': 992,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Welch',
#         'tag': 'NNP',
#         'ner': 'U-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Thomas', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Gogele', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Germany', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Paul', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'McGinley', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Ireland', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'}]}]}]},
#  {'id': 993,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Gary',
#         'tag': 'NNP',
#         'ner': 'B-PER'},
#        {'orth': 'Orr', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Jose-Maria', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Canizares', 'tag': 'NNPS', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Spain', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Michael', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Jonzon', 'tag': 'NNP', 'ner': 'L-PER'}]}]}]},
#  {'id': 994,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '(',
#         'tag': '(',
#         'ner': 'O'},
#        {'orth': 'Sweden', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Paul', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Eales', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'David', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Williams', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Andrew', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Coltart', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'}]}]}]},
#  {'id': 995,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Jonathan',
#         'tag': 'NNP',
#         'ner': 'B-PER'},
#        {'orth': 'Lomas', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Jose', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Rivero', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Spain', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Robert', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Karlsson', 'tag': 'NNP', 'ner': 'L-PER'}]}]}]},
#  {'id': 996,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '(',
#         'tag': '(',
#         'ner': 'O'},
#        {'orth': 'Sweden', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Marcus', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Wills', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Pedro', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Linhart', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Spain', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Jamie', 'tag': 'NNP', 'ner': 'U-PER'}]}]}]},
#  {'id': 997,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Spence',
#         'tag': 'NNP',
#         'ner': 'U-PER'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Terry', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Price', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Australia', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'},
#        {'orth': 'Juan', 'tag': 'NNP', 'ner': 'B-PER'},
#        {'orth': 'Carlos', 'tag': 'NNP', 'ner': 'I-PER'},
#        {'orth': 'Pinero', 'tag': 'NNP', 'ner': 'L-PER'},
#        {'orth': '(', 'tag': '(', 'ner': 'O'},
#        {'orth': 'Spain', 'tag': 'NNP', 'ner': 'U-LOC'},
#        {'orth': ')', 'tag': ')', 'ner': 'O'},
#        {'orth': ',', 'tag': ',', 'ner': 'O'}]}]}]},
#  {'id': 998,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': 'Mark',
#         'tag': 'NNP',
#         'ner': 'B-PER'},
#        {'orth': 'Mouland', 'tag': 'NNP', 'ner': 'L-PER'}]}]}]},
#  {'id': 999,
#   'paragraphs': [{'sentences': [{'tokens': [{'orth': '-DOCSTART-',
#         'tag': '-X-',
#         'ner': 'O'}]}]}]},
#  ...]

# %% [markdown]
# Define a function to convert the ConLL ner data to a format that spaCy understands

# %%
def convert_conll_ner_to_spacy(json_data):
    training_data = []
    set1 = set()
    for j,document in enumerate(json_data):
        sentence_tokens = document['paragraphs'][0]['sentences'][0]['tokens']
        byte_count = 0
        end = None
        full = " ".join([token['orth'] for token in sentence_tokens])
        #print(full)
        entities = []
        for i,token in enumerate(sentence_tokens):
            #print('\n\t' + str(token))
            byte_count += len(token['orth'])
            ner_tag_scheme_list = token['ner'].split('-')
            biluo_scheme = ner_tag_scheme_list[0]
            ner_tag = None

            if biluo_scheme == 'O':
                #print(f'\tbc:{byte_count}')
                pass
            else: 
                set1.add(token['ner'].split('-')[1])
                ner_tag = ner_tag_scheme_list[1]
                if biluo_scheme == 'B':
                    start = byte_count - len(token['orth'])
                elif biluo_scheme == 'I':
                    pass
                elif biluo_scheme == 'L':
                    end = byte_count
                elif biluo_scheme == 'U':
                    start = byte_count - len(token['orth'])
                    end = byte_count
            byte_count += 1      # For a single space between tokens
            if end != None:
                #print(f'\ttoken:{full[start:end]} -- start:{start} end:{end} bc:{byte_count} -- tag:{ner_tag}')
                entities.append((start, end, ner_tag))
                end = None
        training_data.append((full, {"entities" : entities}))
    print(set1)
    return training_data

# %% [markdown]
# Convert training examples into a format that spaCy understands

# %%
training_examples = convert_conll_ner_to_spacy(train_json)
#for t in training_examples + test_examples:
#    print(t)
# Out:
# {'MISC', 'LOC', 'ORG', 'PER'}

# %% [markdown]
# Load pretrained model

# %%
pretrained_nlp = spacy.load('en_core_web_md')

# %% [markdown]
# Load test data and convert it into a format that spaCy understands

# %%
with open('./test.json', 'r') as f:
    read_bytes = f.read()
print(len(read_bytes))
test_json = json.loads(read_bytes)
test_examples = convert_conll_ner_to_spacy(test_json)
# Out:
# 6145340
# {'MISC', 'LOC', 'ORG', 'PER'}

# %% [markdown]
# Define helper functions to :
# * Take convert human annotated examples in spacy format and build a dictionary that maps annotation labels to annotated text. This wil help up in peering into the annotations to find what the labels actually mean.
# * To display the this annotations label to text dictionary
# * Help merging the dictionaries for training and test examples

# %%
import random
def spacy_get_annotations_by_labels(examples_in_spacy_fmt, labels='all'):
    if labels != 'all':
        raise('Not implemented for specific label')
    label_to_text_map =  {} 
    for text,annotations in examples_in_spacy_fmt:
        entities = annotations['entities']
        #print(text)
        for (start, end, label) in entities:
            #print('\t',start, end, label, '\''+text[start:end]+'\'')
            if label not in label_to_text_map:
                label_to_text_map[ label ] = set()
            else:
                label_to_text_map[ label ].add( text[start:end] )
    return label_to_text_map

def display_labels2text_dict(dictionary, num_samples_per_entity):
    temp_dict = {}
    for key, set_ in dictionary.items():
        temp_dict[key] = []
        set_list = list(set_)
        print(f'set_len({key}) = {len(set_)}')
        if len(set_list) < num_samples_per_entity:
            [ temp_dict[key].append(e) for e in set_list ]
        else: 
            for i in range(num_samples_per_entity):
                temp_dict[key].append( set_list[ int(random.random() * len(set_list)) ] )
    pprint(temp_dict, width=200)

def copy_dict(src_dict, dest_dict):
    for label,set_ in src_dict.items():
        if label not in dest_dict:
            dest_dict[label] = set()
        else:
            [ dest_dict[label].add(i) for i in src_dict[label] ]
    return
    
def merge_labels_to_text_dict(dict1, dict2):
    merged_dict = {}
    copy_dict(dict1, merged_dict)
    copy_dict(dict2, merged_dict)
    return merged_dict

# %% [markdown]
# Show the text corresponding the various annotation-labels in the <u>training set<u>

# %%
labels2text_dict_train    = spacy_get_annotations_by_labels(training_examples)
labels2text_dict_test     = spacy_get_annotations_by_labels(test_examples)
merged_dict               = merge_labels_to_text_dict(labels2text_dict_train, labels2text_dict_test)

display_labels2text_dict({'MISC':merged_dict['MISC']}, 302)
# Out:
# set_len(MISC) = 301
# {'MISC': ['Social Democrats',
#           'Holocaust',
#           'ENGLISH',
#           'Algerians',
#           'American',
#           'Polish',
#           'Portuguese',
#           'Arabian Light',
#           'Cup',
#           'Lantau Peak',
#           'Uzbek',
#           'Moroccan',
#           'Pilkington Cup',
#           'Y-GREEN BAY',
#           'MEDITERRANEAN',
#           'Warsaw Pact',
#           'Dow',
#           'African',
#           'World Cup',
#           'Sheffield Shield',
#           'BRAZILIAN',
#           'Minas',
#           'Tasmanian',
#           'office-Conservatives',
#           'East Timorese-born',
#           'AMERICAN',
#           'Spanish',
#           'Greek',
#           'Jones',
#           'East Timorese',
#           'Arabic',
#           'Pro-European',
#           'Tia Juana',
#           'Grand Slam Cup',
#           'Mercedes',
#           'mid-Mississippi',
#           'Queenslander',
#           'Hindus',
#           'Turkish',
#           'post-Communist',
#           "Saturday'sWorld Cup",
#           'Mexican',
#           'Permian',
#           'Full Light',
#           'Hindu',
#           'Indonesians',
#           'WORLD CUP',
#           'Argentine',
#           'Swede',
#           'Yakomas',
#           'CZECH',
#           'Hungarian',
#           'World Championships',
#           'Chinese',
#           'Israeli',
#           'U.S.-based',
#           'Jewish',
#           'Newmont-Santa Fe',
#           'Sangthai Glory',
#           'GRAND SLAM CUP',
#           'Canadian',
#           'WORLD GRAND PRIX',
#           'FOOTBALL-OHIO STATE',
#           'Burmese',
#           'ARAB',
#           'Lucky Emdldm',
#           'Italians',
#           'South African',
#           'Israelis',
#           'Syrian-backed',
#           'ZIMBABWE OPEN',
#           'Italian',
#           'Danila',
#           'Croat',
#           'Bonny Light',
#           'World Grand Prix',
#           'EUROLEAGUE',
#           'Russian-U.S.',
#           'Chilean',
#           'Austrian',
#           'INTERVIEW-ZYWIEC',
#           'Egyptian',
#           'Brazilian',
#           'SKIING-GLADISHIVA',
#           'Super G',
#           'Syrians',
#           "Christian-Shi'ite",
#           'Royal Clipper',
#           'UK-US',
#           'S-MX',
#           'Belgian',
#           '1966 World Cup',
#           'Real Madrid-Barcelona',
#           'Czechs',
#           'Nazi',
#           'sales-USDA',
#           'then-U.S.',
#           'General Agreement on Tariffs and Trade',
#           'ISRAELI',
#           'cocker spaniels',
#           'Ranji Trophy',
#           'Euronotes',
#           'Yakoma',
#           'Jews',
#           'Roman Catholic',
#           'Euro-sceptic',
#           'Seagramd',
#           'European Cup',
#           'F.A. Challenge Cup',
#           'Estonian',
#           'Kenda',
#           'South Korean',
#           'French-owned',
#           'Frenchman',
#           'Europoean Cup',
#           'Mahindra International',
#           'Indonesian',
#           'WORLD SERIES',
#           'MAHINDRA INTERNATIONAL',
#           'IPC',
#           'Japanese',
#           'BOBSLEIGH-SHIMER',
#           'SPANISH',
#           'SCOTTISH PREMIER DIVISION',
#           'pro-Israeli',
#           'Nobel Peace Prize',
#           'Honda RV',
#           'JCPenney Classic',
#           'IRISHMAN',
#           'Nobel',
#           'Daniella',
#           'Africans',
#           'Berne Convention',
#           'Winter Olympics',
#           'Syrian',
#           "European Champions ' League",
#           'Britons',
#           'DUTCH',
#           'Spetses',
#           'Soviet-imposed',
#           'Australian Capital Territory',
#           'Isthmus',
#           'Princess of Loine',
#           'Zairean',
#           'Doberman',
#           'Indian',
#           'Irish',
#           '1995 World Cup',
#           'European',
#           "African Cup Winners ' Cup",
#           'Mauritian',
#           'NYMEX ACCESS',
#           'Koreans',
#           'World Series',
#           'LOMBARDI AWARD',
#           '1993 World Cup',
#           'FRENCH',
#           'British Airways-American',
#           'Bulgarian',
#           'Treasuries',
#           'Dutch',
#           'Asian',
#           'ADRs',
#           'Uruguayan',
#           'Muenchener',
#           'Thai',
#           'BOBSLEIGH-WORLD CUP',
#           'Soviet',
#           'trans-Atlantic',
#           'Moslem',
#           'French',
#           'Internet',
#           'SWISS',
#           'Lula I',
#           'Ugandan',
#           'GERMAN',
#           "Nation 's Cup",
#           'Newsnight',
#           'Olympic',
#           'Scottish',
#           'Yugoslav',
#           'Asia Rubber Markets meeting',
#           'DAX',
#           'CENTRAL DIVISION',
#           'Slovak',
#           'Conservative',
#           'World Open',
#           'Norwegian',
#           'SAfrican',
#           'London-to-Boston',
#           'Dubai',
#           'Tutsi',
#           'TOPS',
#           'X-DENVER',
#           'Australia-West Indies',
#           'Israeli-held',
#           'Lebanese',
#           'Bangkok',
#           'India-South Africa',
#           'Montenegrin',
#           'UEFA Cups',
#           'Czechoslovak',
#           'Australian',
#           'Englishman',
#           'Pan American',
#           'Serie A',
#           'Zulu',
#           'Croatian',
#           'Engllsh',
#           'Dalmatians',
#           'ASIAN CUP',
#           'Palestinian',
#           'Christians',
#           'Europeans',
#           'Saharan Blend',
#           'Washington-based',
#           'Soviet-led',
#           'Singaporean',
#           'BILO',
#           'Swiss',
#           'Rose Bowl',
#           'S.AFRICA',
#           'Canadians',
#           'Premier league',
#           'Zaireans',
#           'Communists',
#           'German shepherds',
#           'English',
#           'Baya',
#           'Liberian',
#           'Roman',
#           'Mesipia',
#           'Moslems',
#           'NYC',
#           'US$',
#           'But',
#           'Asian Cup',
#           'Franco-African',
#           'pro-Hindu',
#           'World War Two',
#           'Codos',
#           'Deligst',
#           'King Ace',
#           'UEFA Cup',
#           'Scottish Cup',
#           'German',
#           'Scottish premier',
#           'Kurdish',
#           'SKIING-WORLD CUP',
#           'SHEFFIELD SHIELD',
#           'Albanian',
#           'Hindu-Moslem',
#           'Iran Sabr',
#           'ENGLISH F.A. CUP',
#           'English F.A. Challenge',
#           'EuroLeague',
#           'Soveit-bloc',
#           'Cambodian',
#           'ENGLISHMAN',
#           'Thai Resource',
#           'Maritime Queen',
#           'Myos Yang',
#           'Democratic Convention',
#           'World cup',
#           'Palestinians',
#           'Learjet 36',
#           'Euro',
#           'Asian Games',
#           'GMT',
#           'Zimbabwe Open',
#           'ITALIAN',
#           'Basque',
#           'Rottweilers',
#           'Korean',
#           'pro-European',
#           'Network',
#           'Lombardi Award',
#           'ZULU',
#           'Russian',
#           'Algerian',
#           'JCPENNEY CLASSIC',
#           'GATT',
#           'Brazilians',
#           'SKIING-CHINESE',
#           'Algoa Day',
#           'SCOTTISH',
#           'Islam',
#           'British',
#           'Kurd',
#           'Budisuryana',
#           'Rwandan',
#           'Communist',
#           'Christian',
#           'Tong Shun',
#           'Europa Cup',
#           'C$',
#           'Americans',
#           "Champions ' League",
#           "AFRICAN CUP WINNERS ' CUP",
#           'ACCESS',
#           'Welsh']}

# %% [markdown]
# Show the text corresponding the various annoatation-labels in the <u>test set<u>

# %%
import random

# Dictionary that maps entities in the pretrained model (en_core_web_xx) to the unique texts of the test set
# they resolve to. So that we know what all texts match a particular entity label. This will help us 
# in understanding which label maps to the labels of the dataset that is used for pre-training.
def spacy_ner_predictions_to_dict(examples_in_spacy_fmt):
    pred_ent_to_text_map = {} 
    for text,_ in examples_in_spacy_fmt:
        pred_doc = pretrained_nlp(text)
        for ent in pred_doc.ents: 
            if ent.label_ not in pred_ent_to_text_map:
                pred_ent_to_text_map[ ent.label_ ] = set()
            else:
                pred_ent_to_text_map[ ent.label_ ].add( ent.text )
    return pred_ent_to_text_map

# Following call takes time. Uncommnet if contents of the parameter has changed
#pred_dict = spacy_ner_predictions_to_dict(test_examples)

display_labels2text_dict(pred_dict, 80)
# Out:
# set_len(GPE) = 572
# set_len(PERSON) = 1099
# set_len(ORG) = 794
# set_len(DATE) = 618
# set_len(EVENT) = 41
# set_len(CARDINAL) = 621
# set_len(ORDINAL) = 28
# set_len(TIME) = 76
# set_len(NORP) = 147
# set_len(QUANTITY) = 86
# set_len(PRODUCT) = 14
# set_len(MONEY) = 162
# set_len(PERCENT) = 58
# set_len(LOC) = 44
# set_len(FAC) = 19
# set_len(WORK_OF_ART) = 9
# set_len(LANGUAGE) = 2
# set_len(LAW) = 4
# {'CARDINAL': ['10,900',
#               '204',
#               '83',
#               '30',
#               '106',
#               '136',
#               '80',
#               '6 1/2',
#               '153,231',
#               '269',
#               '10,900',
#               '369',
#               '1000',
#               '53.01',
#               '74.45',
#               '209',
#               '18,000',
#               'about 120',
#               '10=',
#               '180',
#               '53.29',
#               '302',
#               '44',
#               'half',
#               '41.08',
#               '1:18.98',
#               'more than 160',
#               '18=',
#               '1:46.06',
#               '992,860',
#               '27',
#               '12,200',
#               '69',
#               '54,333',
#               '1.04 million',
#               '136',
#               'between 500,000 and one million',
#               '48,053',
#               'about 120',
#               '1.29',
#               '1:16.38',
#               '1168.9',
#               '4-2',
#               '10 1/2',
#               '1:50.91',
#               '1:16.86',
#               '1:50.91',
#               '126',
#               '29,200',
#               '1:16.47',
#               '73.47',
#               '1:23.17',
#               '1:50.72',
#               '302',
#               '28,418',
#               '106,000',
#               '118',
#               '17',
#               '254',
#               '121',
#               '101',
#               '60,456',
#               '81',
#               '113',
#               '1:16.63',
#               '5',
#               '1 12',
#               '40.78',
#               'several hundred',
#               '59',
#               'More than 290',
#               '194.02',
#               '60,456',
#               '15',
#               '64,334 160,476',
#               '3,333.05',
#               '18',
#               'Four',
#               '7.66 million',
#               '121.3'],
#  'DATE': ['nearly a year',
#           'MONDAY , DECEMBER 9',
#           '16 7 4 5 24 21 25',
#           '2006',
#           'last Tuesday',
#           '75 64',
#           '1986',
#           '1996-12-05',
#           '25 years',
#           '253,821 223,172',
#           '1995',
#           '22 8 2 12',
#           'April 1',
#           '1:17.97',
#           '16 4 4 8 18 28 16',
#           '72 61 68',
#           'the next year',
#           '1:48.91',
#           'this decade',
#           'the next ten years',
#           '73 69',
#           '10 11 4 74 84 24',
#           'Thursday 200',
#           '18 13 3',
#           '14 10',
#           '18 13 3',
#           '22 11 7',
#           'early 1997',
#           '1530',
#           '16 48',
#           '23 33',
#           '6 12',
#           'Jan. 10 , 1997',
#           'Wednesday 1',
#           '15 8 5 2 28 13 29',
#           '12/15/2009',
#           '73 69',
#           '1996',
#           '17-of-34',
#           'THIS WEEKEND',
#           '1986',
#           '22 15 3',
#           '20 39',
#           'January-August',
#           '18 9 3',
#           '9-153',
#           'July 1994',
#           '1994',
#           '20 5 7 8 13 22',
#           '89,300 week ago',
#           'between 1975 and 1981',
#           'SUNDAY , DECEMBER 8',
#           'Yr Ago',
#           'Dec 10',
#           'Jul 97',
#           'Wednesday',
#           'June',
#           'December 6 , 1992',
#           '69 69 69',
#           'November 16',
#           '1989',
#           '14 11',
#           "THURSDAY 'S",
#           '16 11',
#           '1989-90',
#           '68 68 70',
#           '20 8 7 5 21',
#           'Week ago',
#           'march',
#           'next year',
#           'November 27',
#           '14 11',
#           '21 10 4 7 25',
#           '1992',
#           '16 4 5',
#           '25 years',
#           '22 8 8 6 23 21 32',
#           '16 25 18',
#           '33',
#           '1:46.34'],
#  'EVENT': ['Holocaust',
#            'WORLD CUP WEEKEND',
#            'the World Cup quarter',
#            "the African Cup Winners ' Cup",
#            'WORLD CUP SUPER G',
#            'Asian Cup',
#            'the European Cup',
#            'World Series',
#            'World War Two',
#            'the Super 12',
#            'the World War Two',
#            'Scottish Cup',
#            'an Asian Cup',
#            'World Cup',
#            'Wosz 89th',
#            'the New Year',
#            'a World Series',
#            "Nation 's Cup",
#            'Fair Play',
#            'the World Cup',
#            'World cup',
#            'the World Series',
#            'a World Cup',
#            'WORLD CUP DOWNHILL',
#            'Asian Games',
#            'the Zimbabwe Open',
#            'the 1991 World Championships',
#            'Lillehammer Winter Olympics',
#            'WORLD CUP',
#            'the World Grand Prix',
#            'world cup circuit',
#            'World Cup Super G',
#            'the Uruguay Round',
#            'the Europoean Cup',
#            'Nobel',
#            'the Mahindra International',
#            'Berne Convention',
#            'Europa Cup',
#            'World Cup biathlon',
#            'the World Open',
#            'the UEFA Cup'],
#  'FAC': ['the Rose Bowl',
#          'Arabian Light',
#          'the Sydney Cricket Ground',
#          'Downing Street',
#          'the Melbourne Cricket Ground',
#          'Sheffield Shield',
#          'the Innisbrook Hilton Resort',
#          'Pontypridd 53 Bridgend',
#          'Shwe Dagon pagoda',
#          'the Rotary Club',
#          'Vieira 90',
#          'Munich 1 (',
#          'GMT',
#          'Leicester 1 Blackburn',
#          'the National stadium',
#          'the Goma-Bukavu',
#          'TAMPA BAY',
#          'Shannon',
#          'Vatican'],
#  'GPE': ['Bombay',
#          'Los Angeles',
#          'BRATISLAVA',
#          'UK',
#          'UAE',
#          'Calcutta',
#          'ANAHEIM',
#          'Czech Republic',
#          'MEDITERRANEAN',
#          'British Columbia',
#          'Timisoara',
#          'Milan',
#          'Albania',
#          'Vietnam',
#          'the Australian Capital Territory',
#          'Finland',
#          'Fort Worth',
#          'United Arab Emirates 3 Kuwait',
#          'Pilsen',
#          'Macedonia',
#          'Doncaster',
#          'MILWAUKEE',
#          'Denmark',
#          'New York City',
#          'UK',
#          'Lisbon',
#          '12/15/2005',
#          'Denmark',
#          'Tokyo',
#          'Ireland',
#          'Bournemouth',
#          'PITTSBURGH',
#          'PORTLAND',
#          'Arizona State',
#          'Mauritania',
#          'Albania',
#          'FRANKFURT',
#          'Brunei',
#          'Wallaby',
#          'HANOVER',
#          'COLORADO',
#          'CSKA',
#          'Kenya',
#          'MANCHESTER',
#          'Olympiakos',
#          'Sheffield United',
#          'East Stirling',
#          'Japan',
#          'Izingolweni',
#          'MILWAUKEE',
#          'Iowa',
#          'Boston',
#          'Algiers',
#          'Copenhagen',
#          "Central Africa 's",
#          'Tamaulipas',
#          'Celtic Glasgow',
#          'Albuquerque',
#          'Czech Republic',
#          'Bonn',
#          'VIENNA',
#          'Kazanluk',
#          'Tianjin',
#          'Atletico',
#          'Ayr',
#          'Iowa',
#          'Finland',
#          'Barnet',
#          'mid-Mississippi',
#          'SEATTLE',
#          'Karachi',
#          'Soviet republic',
#          'United States',
#          'Wellington',
#          'MIAMI',
#          'AZ Alkmaar',
#          'Algeria',
#          'USA',
#          'the Soviet Union',
#          'Chesterfield'],
#  'LANGUAGE': ['Arabic', 'English'],
#  'LAW': ["State Law and Order Restoration Council 's", 'Chapter Seven', 'State Law and Order Restoration Council', 'the General Agreement on Tariffs and Trade'],
#  'LOC': ['Caribbean',
#          'Panhandle',
#          'the Po River',
#          'NFC East',
#          'North America',
#          'the East Coast',
#          'Bellerive Oval',
#          'Gulf',
#          'the Miami Dolphins',
#          'Thunder Bay',
#          'Central Asia',
#          'Costa',
#          'Africa',
#          'Asia',
#          'trans-Atlantic',
#          'Interrosimpex',
#          'RED SEA',
#          'West',
#          'Pacific Coast',
#          'North West',
#          'the Gulf of Mexico',
#          'GREEN BAY',
#          'NEW ENGLAND',
#          'East Timorese',
#          'Far North',
#          'East',
#          'Whistler Mountain',
#          'Europe',
#          'Red Sea',
#          'South America',
#          'Southwest',
#          'the West Coast',
#          'Gulf Coast',
#          'KwaZulu-Natal',
#          'Radiometer H1',
#          'West Ham',
#          'Mediterranean',
#          'Rangoon',
#          'Colts',
#          "Latin America 's",
#          'Indian Ocean',
#          'Newmont',
#          'the Ranyon ( Rangoon',
#          'West Coast'],
#  'MONEY': ['about 16,000 francs',
#            '0.12 cents',
#            '26.5 cents',
#            '3.40s',
#            '3.35',
#            'millions of dollars',
#            '3.11',
#            '7.2 154.1 235.7',
#            '25 cents',
#            'more than 15 cents',
#            'more than $ 100,000',
#            '9.90',
#            '32 cent',
#            '$ 40 million',
#            '224 million zlotys',
#            '1.84 billion',
#            '12 cents',
#            '67',
#            '23.50',
#            '4,500 pounds',
#            '15.625',
#            '16 6 6 4 25',
#            '4.40s',
#            '23.50',
#            '5.85',
#            '20,000',
#            '19/12-2/1 $',
#            '75 cents',
#            '0.30',
#            'approximately US$ 24 billion',
#            '3.47',
#            '40.0 561.0 391.9',
#            '46.6 mln kroons',
#            '67',
#            '$ 775 million',
#            '5.25',
#            '3.186',
#            '16 6 6 4 25',
#            '$ 30.3 million',
#            'C$ per cwt',
#            '16 6 6 4 25',
#            '7.6 million zlotys',
#            '17 9 2 6 18 15 29',
#            '25 cents',
#            '3,000',
#            'more than $ 100 million',
#            'billion-dollar',
#            '12 5 1 6 10 11',
#            '14,563',
#            'daytime trade 78 cents',
#            'more than 15 cents',
#            '0.50',
#            '224 million zlotys',
#            '$ 5.8 million',
#            '35.63',
#            '1',
#            '$ 11 mln',
#            '0.09 cents',
#            '7,400',
#            '460,000 Swiss francs',
#            'almost 15 cents',
#            '9.90',
#            '1,000',
#            '4.40s',
#            '47,000 24,300',
#            'only dollar',
#            '$ 10 billion',
#            '143.56 yen',
#            '460,000 Swiss francs',
#            '23.50',
#            'millions of dollars',
#            'billions of yen',
#            'five marks',
#            '$ 40 million',
#            '14,563',
#            '1 - Nick Popplewell',
#            '$ 350 million',
#            'about $ 3 to $ 109',
#            'only dollar',
#            '15.575'],
#  'NORP': ['Skinheads',
#           'Gabon',
#           'Scottish',
#           'South Korean',
#           'Brazilian',
#           'Brazilians',
#           'South Korean',
#           'Canadians',
#           'pro-Hindu',
#           'Jewish',
#           'Jews',
#           'French',
#           'French',
#           'Israeli',
#           'Canadians',
#           'pro-European',
#           'Estudiantes',
#           'Balkan',
#           'post-Communist',
#           'Portuguese',
#           'SOCCER -',
#           'European',
#           'Singaporean',
#           'Scottish',
#           'Rwandan',
#           'rabbi',
#           'Conservatives',
#           'Nazi',
#           'Chilean',
#           'South African',
#           'Albanian',
#           'German',
#           'Frenchman',
#           'Moslem',
#           'Russian',
#           'Italian',
#           'Koreans',
#           'Portuguese',
#           'Campese',
#           'French',
#           'Estonian',
#           'Yugoslav',
#           'Zaireans',
#           'Norwegian',
#           'Roman Catholic',
#           'Europeans',
#           'Roman Catholic',
#           'Western',
#           'Thai',
#           'Zaireans',
#           'Indonesians',
#           'French',
#           'Turkish',
#           'Moslem',
#           'Korean',
#           'Norwegian',
#           'Czechs',
#           'Jews',
#           'Chinese',
#           'Scalfaro',
#           'Central African',
#           'Italians',
#           'Turkish',
#           'Canadian',
#           'Britons',
#           'Croatian',
#           'Italian',
#           'Estudiantes',
#           'Australian',
#           'Estudiantes',
#           'Uruguayan',
#           'Argentine',
#           'Christians',
#           'Moslems',
#           'European',
#           'Estudiantes',
#           'Qinglan',
#           'Estonian',
#           'Basque',
#           'Yakoma'],
#  'ORDINAL': ['12th',
#              'third',
#              'fourth',
#              'Third',
#              '18th',
#              'ninth',
#              '37th',
#              'fifth',
#              '13th',
#              '16th',
#              '88th',
#              '10th',
#              '20th',
#              '84th',
#              '14th',
#              'First',
#              'second',
#              '85th',
#              'seventh',
#              '8th',
#              'SECOND',
#              '15th',
#              'FIRST',
#              'THIRD',
#              'first',
#              '55th',
#              '38th',
#              '2nd'],
#  'ORG': ['Hamburger SV 16 4 5 7',
#          'La Clippers',
#          'Zywcu SA',
#          'Santa Fe',
#          'Twente Enschede',
#          'Aberdeen',
#          'Cooke',
#          'F.A. Challenge Cup',
#          'United City Bank',
#          'Sidek',
#          'Aberdeen',
#          'NORTHEAST',
#          'Horinouchi',
#          'Tottenham',
#          'Auxerre',
#          'Fiorentina',
#          'the New South Wales Supreme Court',
#          'Heineken',
#          'Fortuna Dusseldorf',
#          'Office of Fair Trading',
#          'the International Monetary Fund',
#          'Justin',
#          'UNITED NATIONS',
#          'Cabinet',
#          'Valladolid',
#          'State Street Bank and Trust Company',
#          'Conservative party',
#          'RIBALTA',
#          'Defenders - Rudi Vata',
#          'Avg',
#          'Germay',
#          'Eagles',
#          'London Heathrow',
#          'New York Commodities Desk',
#          'Konterman',
#          'ISEAS',
#          'Wijaya',
#          'Mercedes',
#          'Telkom',
#          'National League for Democracy',
#          'ASEAN',
#          'DETROIT',
#          'PKK',
#          'Barnet 3 Wycombe 3',
#          'the National Hockey League',
#          'Sunderland',
#          'CRICKET - WOOLMER',
#          'Rangoon University',
#          'Frederick',
#          'Barrick 75 percent',
#          'National Hockey',
#          "Budapest Bank 's",
#          'DURBAN',
#          'SOCCER -',
#          'Costa',
#          'The UK Department of Transport',
#          'Mobil',
#          'breakman Randy Jones',
#          'Nebraska',
#          'SOCCER - GERMAN FIRST',
#          'Cardiff 0 Gillingham',
#          'World Trade Organisation',
#          'Schalke 2 ( Mulder 2nd and',
#          'National Bucharest',
#          'Middlesbrough 0 Leeds',
#          'Salomon',
#          'UNITED NATIONS',
#          'Rangers',
#          'Treasury',
#          'Green Bay Packers',
#          'The Canadian Wheat Board',
#          'ABIDJAN',
#          'Congress',
#          'Burnley',
#          'NFC',
#          'the Civil Aviation Authority',
#          'Piacenza',
#          'La Clippers',
#          'the National Hockey League',
#          'Celtic 1'],
#  'PERCENT': ['69 73 71',
#              'five percent',
#              '3.41 percent',
#              '0.07 percent',
#              '0.05 percent',
#              '130 percent',
#              '11.4 percent',
#              'only 25 percent',
#              'about 55 percent',
#              '60 percent',
#              '4.5 percent',
#              '160 percent',
#              '0.38 percent',
#              '4 percent',
#              '6.51 percent',
#              'minus 1.54 percent',
#              'only 0.27 percent',
#              '0.80 percent',
#              '0.28 percent',
#              '0.85 percent',
#              'minus 0.24 percent',
#              '5.8 percent',
#              '10 percent',
#              'three to five percent',
#              '22.5 percent',
#              '135 percent',
#              '1.8 %',
#              '21.8 % - 4.4 %',
#              '30 percent',
#              '50 percent',
#              '170 percent',
#              'about three percent',
#              '0.68 percent',
#              '4.5 %',
#              '43.56 percent',
#              'seven percent',
#              '120 percent',
#              '2.21 percent',
#              'minus 0.59 percent',
#              '150 percent',
#              'more than 20 percent',
#              '0.02 percent',
#              'one percent',
#              '77 percent',
#              'more than eight percent',
#              '25 percent',
#              'at least 15 percent',
#              '22.00 / 22.75 percent',
#              '85 percent',
#              '1.35 percent',
#              'two percent',
#              '0.37 percent',
#              'three percent',
#              '195 percent',
#              '13.6 percent',
#              '80 percent',
#              'minus 3.03 percent',
#              '105 percent'],
#  'PERSON': ['Dietmar Beiersdorfer',
#             'Shahid Afridi',
#             'Marcelo Otero',
#             'Panutan Duta',
#             'Chris',
#             'Healy',
#             'Paolo Vaccari',
#             'Bure',
#             'Mohammed',
#             'Fabio Cannavaro',
#             'Hansenne',
#             'G. Blewett',
#             'Reich',
#             'Hannes Conti',
#             'Francesco Mazzariol',
#             'Yakomas',
#             'Igor Shkvyrin',
#             'Xue Rulhong',
#             'Chris Hunt',
#             'Shimon Peres',
#             'Tim Gavin',
#             'TEMBAU DENPASAR',
#             'Nigel Walker',
#             "Tony Greig 's",
#             'Dion',
#             'Dili',
#             'Ingeborg Helen Marken',
#             'Claude Makelele',
#             'Emdldm',
#             'Tan',
#             'Harris',
#             'Sinton',
#             'C. Hooper',
#             'Ahmed Abdel-Rahman',
#             'Alexander Livshits',
#             'Marco Caputo',
#             'Mario Stanic',
#             'Hapoel Haifa',
#             'Hiroshi Nanami',
#             'Duce',
#             'Foucras',
#             'John Paul',
#             'Waqar Younis',
#             'Michael Heseltine',
#             'Bogdan Stelea',
#             'Rashid Sidek',
#             'Marcelo',
#             'Steaua Bucharest',
#             'Giambatista Croci',
#             'Hapoel Taiba',
#             'Eric Cleymans 18',
#             'Ronaldo',
#             'Megan Gerety',
#             'Stranraer 0',
#             'Stuart Law',
#             'Kim Byung',
#             "Jack Charlton 's",
#             'Ramthan Hussain',
#             'Sociedad',
#             'Greg Blewett',
#             'Jeremie Collomb-Patton',
#             'Miyabe Yasunori',
#             'Miyabe Yasunori',
#             'Hines',
#             'Jacques Stas',
#             'Clinton',
#             'Ricco Gross',
#             'Dennis Luebke',
#             'Hereford',
#             'Alessandra Merlin',
#             'Shimizu Hiroyasu',
#             'Dion Fourie',
#             'Jonathan Wright',
#             'Rosario Bahia',
#             'Albion v Forfar',
#             'Abdel-Rahman',
#             'Yasser Arafat',
#             "Naoki Soma 's",
#             'Ramthan Hussain',
#             'Pau-Orthez'],
#  'PRODUCT': ['Zywiec Full Light', '71.39-76.12', 'Classic', 'Sheffield Shield', 'Blinker', 'Okabe 146', 'Sutton 34', 'Colts', '72.41 72.07', 'Lahd', 'Rinaco Plus', 'the S-MX', 'S-MX', 'Wallaby'],
#  'QUANTITY': ['578,000 tonnes',
#               '16 km',
#               '16 km',
#               '11-8 11-3',
#               '40 miles',
#               '1150-1200 lbs 67.00',
#               'one mile',
#               'about two km',
#               'about 65 km',
#               '15-10 15-6',
#               'four miles',
#               '11-6 12-10',
#               '44 yards',
#               '145,000 tonnes',
#               '570 km',
#               'six km',
#               'hundred lbs',
#               'about two km',
#               'up to 695,000 tonnes',
#               '29 lb',
#               '51,000 tonnes and 319,000 tonnes',
#               '5,000 deadweight-tonne',
#               '1100-1200 lbs 112.00',
#               '1.233 million tonnes',
#               'up to 75 km an hour',
#               'one mile',
#               'three to five feet',
#               'dozens of kilos',
#               '57 million ounces',
#               '13 kg',
#               'thousands of tonnes',
#               '20 kg',
#               'six km',
#               'three to five feet',
#               'eight kg',
#               '1250-1400 lbs',
#               '101 yards',
#               '10 kms',
#               '20 kg',
#               '1100-1200 lbs 112.00',
#               'around 40 litres',
#               'about 914,000 tonnes',
#               '15-8 15-2',
#               'eight kg',
#               '50,000 tonnes',
#               '32,970,000 1,305,000 88,800,000',
#               '5,000 deadweight-tonne',
#               '13= Picabo Street',
#               '746,000 tonnes',
#               '7.5 kms',
#               '33 yards',
#               '310 miles',
#               '44 lbs',
#               '10 to 15 knots',
#               '20-1 Fernando Hierro',
#               '13= Picabo Street',
#               '547,000 tonnes',
#               '500 metres',
#               'up to 75 km an hour',
#               '44 yards',
#               '4.4 15.1 87.0 0.6 22.1',
#               '310 miles',
#               '500 metres',
#               '1150 lbs',
#               'hundred lbs',
#               '16 km',
#               '145,000 tonnes',
#               '20-1 Fernando Hierro',
#               'up to six feet',
#               '51,000 tonnes and 319,000 tonnes',
#               '134,085 tonnes',
#               '9 6 3 15',
#               '29 lb',
#               '32,970,000 1,305,000 88,800,000',
#               '50,000 tonnes',
#               "000 's tonnes",
#               '29 lb',
#               '547,000 tonnes',
#               'about 10 miles',
#               'six km'],
#  'TIME': ['about 3 A.M.',
#           'minute 45.91 seconds',
#           'around 1 a.m.',
#           '18 5 2 11 16 23 17',
#           '21 12 6 3 34',
#           '12 10 2',
#           '22 10 6 6 29 25 36',
#           'the last six minutes',
#           '18 5 6 7',
#           '12/15/2001 575M 4.60 4.20',
#           '12/15/2004 625M 4.50 4.50',
#           'night',
#           'about 0600',
#           '2:22',
#           'about 3 a.m.',
#           '16 9 4 3 33 17 31',
#           'just minutes',
#           'the 53rd minute',
#           'afternoon',
#           '1 minute 16.24 seconds',
#           '12/15/2014 850M 5.30 5.35',
#           '65 minutes',
#           'one minute 17.76 seconds',
#           'a night',
#           '129 minutes',
#           'earlier in the day',
#           'eight km an hour',
#           'just hours',
#           'the night of Friday to Saturday',
#           '0930 GMT',
#           'only the fifth minute',
#           'A minute later',
#           '7:13 a.m. EST',
#           '15 4 5',
#           '5 6 11 24 41 21',
#           'LAST-MINUTE',
#           '19 6 3 10 21 25 21',
#           'one minute 47.71 seconds',
#           'the final five seconds',
#           '15 7 5 3 29',
#           'hours',
#           'later in the day',
#           'the first 55 minutes',
#           '4:30 A.M. EST',
#           'only 40 minutes',
#           'three minutes',
#           'PM',
#           '15 1 6 8 12 25 9',
#           '37.23 seconds',
#           'last-minute',
#           '1:30 A.M. EST',
#           '4 PM',
#           'up to four hours',
#           'two hours',
#           '26 minutes 17.2 seconds',
#           'the first few hours',
#           'less than one hour',
#           '16 7 6 3 23 21 27',
#           'the coming hours',
#           '20 minutes',
#           '9 9 3 24 18',
#           'four minutes',
#           '50 minutes',
#           'overnight',
#           'late Friday',
#           'morning',
#           '21 6 6 9 16 19 24',
#           'Thursday night',
#           'the 88th minute',
#           '30 minutes',
#           '0630 GMT',
#           '5.15 5.15 5.30 5.30 5.60 5.60 5.90 5.90',
#           'one minute 45.91 seconds',
#           'minutes',
#           'evening',
#           'minute'],
#  'WORK_OF_ART': ['the Lombardi Award', 'Nobel Peace Prize', 'Tomorrow', 'Mr Yen', 'Nobel', 'Newsnight', 'the Nobel Peace Prize', 'The Super Peasants', 'Wimbledon']}

# %%
spacy.explain('NORP')
# Out:
# 'Nationalities or religious or political groups'

# %% [markdown]
# The NER entities of SpaCy and the manually annotated labels of the dataset dont match. So we need to map those labels to the closest entities that SpaCy's NER model deals with.

# %%
PRED_LABELS_EQUIV_MAP = {
    'NORP'       : 'MISC',
    'WORK_OF_ART': 'MISC',
    'FAC'        : 'MISC',
    'PRODUCT'    : 'MISC',
    'EVENT'      : 'MISC',
    'GPE'        : 'LOC',
    'LOC'        : 'LOC',
    'ORG'        : 'ORG', 
    'PERSON'     : 'PER'
}

# %% [markdown]
# Evaluating spaCy's pretrained model on test examples. This score would be compared with the score on the same model which has been retrained on the training data. We count the
# * Number of true positives  - Labelled correctly
# * Number of false positives - Labelled and did not got it correct AND those that should not have been labelled.
# * Number of false negatives - Those that were not labelled at all

# %%
def print_annotaions_and_predictions(spacy_examples):
    for text,annotation in spacy_examples:
        pred_doc = pretrained_nlp(text)
        ypred = [ (ent.label_,ent.text) for ent in pred_doc.ents ]
        
        annot_list = [( ent[2], text[ent[0]:ent[1]] ) for ent in annotation['entities']]
        
        print('Human annotated: ', annot_list)
        print('Predictions    : ', ypred)
        print('\n')

def map_pred_tag_to_domain(pred_bilou_tag, equivalence_map):
    if pred_bilou_tag[0] == 'O':
        return 'O'
    bilou_part = pred_bilou_tag.split('-')[0]
    label_part = pred_bilou_tag.split('-')[1]
        
    if label_part not in equivalence_map.keys():
        return 'O'
    return bilou_part + '-' + equivalence_map[label_part]

def convert_doc_to_bilou_tags(doc):
    list_ = [] 
    for i in range(len(doc)):
        # Process BILOU tag
        if doc[i].ent_iob_ == 'O':
            bilou_tag = 'O'
        else:
            if doc[i].ent_iob_ == 'B':
                bilou_tag = 'U' if (i+1) < len(doc) and doc[i+1].ent_iob_ != 'I' else 'B'
            elif doc[i].ent_iob_ == 'I':
                bilou_tag = 'I' if (i+1) < len(doc) and doc[i+1].ent_iob_ == 'I' else 'L'
            else:
                assert "This is unexpected"
        bilou_tag = 'O' if doc[i].ent_type_ == '' else bilou_tag + '-' + doc[i].ent_type_
        
        list_.append( (bilou_tag, doc[i].text) )    
    #print('--->> ',list_)
    return list_

def perf_measure(y_actual, y_hat, label):
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    for i in range(len(y_hat)):
        if y_actual[i]==y_hat[i]==label:
            TP += 1
        if y_hat[i]==label and y_actual[i]!=label:
            FP += 1
        if y_actual[i]!=label and y_hat[i]!=label:
            TN += 1
        if y_hat[i]!=label and y_actual[i]==label:
            FN += 1
    return(TP, FP, TN, FN)

def compute_scores_2(spacy_examples, model, label_map):
    perf_stats_per_tag = { }
    for text,annotation in spacy_examples:
        doc = model.make_doc(text)
        gold = GoldParse(doc, entities=annotation['entities'])
        gold_tag_list = [i for i in zip(gold.ner,gold.words)]
        #print('\nGold       : ', gold_tag_list)
        
        ner_tag_predict_doc = model(text)
        ner_tag_predict_list = convert_doc_to_bilou_tags(ner_tag_predict_doc)
        ner_tag_predict_list = list( map(lambda e: (map_pred_tag_to_domain(e[0],PRED_LABELS_EQUIV_MAP), e[1]), 
                                         ner_tag_predict_list) 
                                   )
        #print(  'Predicted  : ', ner_tag_predict_list)
        
        #for i in range(len(ner_tag_predict_list)):
        #    if ner_tag_predict_list[i][0] != gold_tag_list[i][0]:
        #        print('\t',ner_tag_predict_list[i], gold_tag_list[i])
        #        continue
        #    if ner_tag_predict_list[i][1] != gold_tag_list[i][1]:
        #        print('\t',ner_tag_predict_list[i], gold_tag_list[i])
        #        continue
        
        # Compute unique labels and populate y_true and y_pred
        unique_labels = set()
        y_true, y_pred = [],[]
        for t in gold_tag_list:
            if t[0] != 'O':
                unique_labels.add( t[0] )
            y_true.append( t[0] )
        for t in ner_tag_predict_list:
            if t[0] != 'O':
                unique_labels.add( t[0] )
            y_pred.append( t[0] )
            
        #print('\tUnique Labels :', unique_labels)
        #print('\ty_true        :', y_true)
        #print('\ty_pred        :', y_pred)
        for label in unique_labels:
            (TP, FP, TN, FN) = perf_measure(y_true, y_pred, label)
            CNT = len(y_true)
            #print(label,' ',f'(TP:{TP}, FP:{FP}, TN:{TN}, FN:{FN}, CNT:{CNT})')
            
            label_part = label.split('-')[1]
            if label_part not in perf_stats_per_tag:
                perf_stats_per_tag[label_part] = {'TP':0, 'FP':0, 'TN':0, 'FN':0, 'CNT':0}
                
            perf_stats_per_tag[label_part]['TP'] += TP
            perf_stats_per_tag[label_part]['FP'] += FP
            perf_stats_per_tag[label_part]['TN'] += TN
            perf_stats_per_tag[label_part]['FN'] += FN
            perf_stats_per_tag[label_part]['CNT'] += CNT
    return perf_stats_per_tag

def display_perf_stats_per_tag( stats_per_tag ):
    # Now compute the scores
    pprint(stats_per_tag)
    for tag,st in stats_per_tag.items():
        print(f'For label: "{tag}"')
        accuracy = (st['TP'] + st['TN']) / st['CNT']
        print("\tAccuracy : "  + str(accuracy * 100) + "%")
        
        precision = 0
        if (st['TP'] + st['FP']) != 0:
            precision = st['TP'] / (st['TP'] + st['FP'])
        print("\tPrecision : " + str(precision))
        
        recall = 0
        if (st['TP'] + st['FN']) != 0:
            recall = st['TP'] / (st['TP'] + st['FN'])
        print("\tRecall : "    + str(recall))
        
        fscore = 0
        if (precision + recall) != 0:
            fscore = (2 * precision * recall) / (precision + recall)
        print("\tF-score : "   + str(fscore))
        


        
#print_annotaions_and_predictions(test_examples)

stats_per_tag__on_vanilla_md = compute_scores_2(test_examples, pretrained_nlp, PRED_LABELS_EQUIV_MAP)
display_perf_stats_per_tag(stats_per_tag__on_vanilla_md)
# Out:
# {'LOC': {'CNT': 36306, 'FN': 453, 'FP': 791, 'TN': 33571, 'TP': 1491},
#  'MISC': {'CNT': 23206, 'FN': 468, 'FP': 276, 'TN': 21906, 'TP': 556},
#  'ORG': {'CNT': 50164, 'FN': 1462, 'FP': 1431, 'TN': 46196, 'TP': 1075},
#  'PER': {'CNT': 45528, 'FN': 608, 'FP': 648, 'TN': 42053, 'TP': 2219}}
# For label: "LOC"
# 	Accuracy : 96.57356910703466%
# 	Precision : 0.6533742331288344
# 	Recall : 0.7669753086419753
# 	F-score : 0.705631803123521
# For label: "PER"
# 	Accuracy : 97.24125812686698%
# 	Precision : 0.77397976979421
# 	Recall : 0.7849310222851079
# 	F-score : 0.7794169301018616
# For label: "ORG"
# 	Accuracy : 94.23291603540387%
# 	Precision : 0.4289704708699122
# 	Recall : 0.423728813559322
# 	F-score : 0.42633353162799914
# For label: "MISC"
# 	Accuracy : 96.79393260363699%
# 	Precision : 0.6682692307692307
# 	Recall : 0.54296875
# 	F-score : 0.5991379310344827

# %% [markdown]
# Now lets <b><u>retrain</u></b> the SpaCy model on out training data

# %%
import copy 
def conv_dataset_to_match_domain(spacy_examples, dataset_to_model_tag_map):
    spacy_examples = copy.deepcopy(spacy_examples)
    for text,annotations in spacy_examples:
        entities = annotations['entities']
        for i,ent in enumerate(entities):
            if ent[2][0] == 'O':
                continue
            entities[i] = (ent[0],ent[1],dataset_to_model_tag_map[ent[2]])                                        
    return spacy_examples

# The 'model' parameter could either be a pretrained model. Default behavior is to 
# training from scratch. 
def train_spacy_model(train_examples, model=None):
    nlp = model  # create blank Language class
    if nlp == None:
        nlp = spacy.blank('en')
    
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if model == None:
        if 'ner' not in nlp.pipe_names:
            ner = nlp.create_pipe('ner')
            nlp.add_pipe(ner, last=True)
        # add labels
        for _, annotations in train_examples:
             for ent in annotations.get('entities'):
                ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(10):
            print("Statring iteration " + str(itn))
            random.shuffle(train_examples)
            losses = {}
            for text, annotations in train_examples:
                try:
                    nlp.update(
                        [text],         # batch of texts
                        [annotations],  # batch of annotations
                        drop=0.2,       # dropout - make it harder to memorise data
                        sgd=optimizer,  # callable to update weights
                        losses=losses)
                except:
                    continue
                    #print('Hello ' + str(sys.exc_info()))
            print(losses)
    return nlp

dataset_to_model_tag_map = { 'MISC': 'NORP',
                             'LOC' : 'LOC',
                             'ORG' : 'ORG',
                             'PER' : 'PERSON'}
mapped_examples = conv_dataset_to_match_domain(training_examples, 
                                               dataset_to_model_tag_map)
#train_spacy_model(mapped_examples, pretrained_nlp)

# %% [markdown]
# Evaluating spaCy's <b><u>retrained</u></b> model on test examples

# %%
# saved_model = copy.deepcopy(pretrained_nlp) # *ExpensiveResource*. comment after execution

#stats_per_tag__retrained = compute_scores_2(test_examples, saved_model, PRED_LABELS_EQUIV_MAP)
display_perf_stats_per_tag(stats_per_tag__retrained)
# Out:
# {'LOC': {'CNT': 34285, 'FN': 243, 'FP': 416, 'TN': 31925, 'TP': 1701},
#  'MISC': {'CNT': 23083, 'FN': 304, 'FP': 218, 'TN': 21841, 'TP': 720},
#  'ORG': {'CNT': 41865, 'FN': 673, 'FP': 359, 'TN': 38969, 'TP': 1864},
#  'PER': {'CNT': 43017, 'FN': 273, 'FP': 251, 'TN': 39939, 'TP': 2554}}
# For label: "LOC"
# 	Accuracy : 98.07787662242964%
# 	Precision : 0.8034955125177138
# 	Recall : 0.875
# 	F-score : 0.8377246983501601
# For label: "PER"
# 	Accuracy : 98.78187693237557%
# 	Precision : 0.9105169340463458
# 	Recall : 0.9034311991510435
# 	F-score : 0.9069602272727272
# For label: "ORG"
# 	Accuracy : 97.53493371551414%
# 	Precision : 0.8385065227170491
# 	Recall : 0.7347260543949546
# 	F-score : 0.7831932773109245
# For label: "MISC"
# 	Accuracy : 97.73859550318417%
# 	Precision : 0.767590618336887
# 	Recall : 0.703125
# 	F-score : 0.7339449541284404

# %% [markdown]
# Now lets train a model <b><u>from sratch</u></b> and compute the score. The idea here would be to see if the performance on the retrained spaCy model is better than that of on a model that has been trained from scratch

# %%
#model_from_scratch = train_spacy_model(training_examples)
#stats_per_tag__from_scratch = compute_scores_2(test_examples, model_from_scratch, PRED_LABELS_EQUIV_MAP)
display_perf_stats_per_tag(stats_per_tag__from_scratch)
# Out:
# Statring iteration 0
# {'ner': 20394.866084106878}
# Statring iteration 1
# {'ner': 13091.086114697599}
# Statring iteration 2
# {'ner': 10036.00885534475}
# Statring iteration 3
# {'ner': 8481.742086296188}
# Statring iteration 4
# {'ner': 7155.71140668863}
# Statring iteration 5
# {'ner': 6390.112653583615}
# Statring iteration 6
# {'ner': 5746.511855209186}
# Statring iteration 7
# {'ner': 5282.283485583606}
# Statring iteration 8
# {'ner': 5020.81613579561}
# Statring iteration 9
# {'ner': 5065.791847710549}
# {'LOC': {'CNT': 31682, 'FN': 428, 'FP': 248, 'TN': 29490, 'TP': 1516},
#  'MISC': {'CNT': 19528, 'FN': 1024, 'FP': 0, 'TN': 18504, 'TP': 0},
#  'ORG': {'CNT': 49463, 'FN': 610, 'FP': 914, 'TN': 46012, 'TP': 1927},
#  'PER': {'CNT': 39024, 'FN': 2827, 'FP': 0, 'TN': 36197, 'TP': 0}}
# For label: "ORG"
# 	Accuracy : 96.91890908355741%
# 	Precision : 0.6782822949665611
# 	Recall : 0.759558533701222
# 	F-score : 0.7166232800297508
# For label: "PER"
# 	Accuracy : 92.75574005740057%
# 	Precision : 0
# 	Recall : 0.0
# 	F-score : 0
# For label: "LOC"
# 	Accuracy : 97.86629631967679%
# 	Precision : 0.8594104308390023
# 	Recall : 0.779835390946502
# 	F-score : 0.8176914778856526
# For label: "MISC"
# 	Accuracy : 94.75624743957395%
# 	Precision : 0
# 	Recall : 0.0
# 	F-score : 0
